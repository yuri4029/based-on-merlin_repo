# %% [markdown]
# # Quantum optical reservoir computing powered by boson sampling
#
# This approach builds upon prior work by [Sakurai and al.](https://opg.optica.org/opticaq/abstract.cfm?URI=opticaq-3-3-238).
#
# This notebook demonstrates the **Quantum Optical Reservoir Computing (QORC)** experiment using the _MerLin_ quantum machine learning framework. The code replicates the performance results of quantum feature-based classification on the MNIST dataset, showcasing the proof-of-concept benefits of quantum reservoirs for machine learning tasks.
#
# QORC leverages **boson sampling** to compute highly non-linear quantum features from input data. These features, generated through photonic circuits, capture complex patterns that are difficult to extract classically. A classical linear layer is then trained on these quantum-encoded features, forming a hybrid quantum-classical classifier. This approach demonstrates how quantum reservoirs can outperform classical feature extraction by leveraging the exponential expressivity of photonic circuits, enabling enhanced classification performance on complex datasets.

# %% [markdown]
# ## 1. Parameters definition

# %%
# Main parameters
n_photons = 3
n_modes = 20
seed = 42

# Dataset parameters
dataset_name = "mnist"
fold_index = 0
n_fold = 5

# Training parameters
n_epochs = 100
batch_size = 100
learning_rate = 0.05
reduce_lr_patience = 10
reduce_lr_factor = 0.5
num_workers = 0
pin_memory = False
f_out_weights= "f_weights_out.pth"

# Other parameters
b_no_bunching = True
b_use_tensorboard = False
device_name = "cpu"
outdir = "outdir"

# %% [markdown]
# ### Parameters explanation
#
# #### Photonic Circuit Parameters
#
# - **n_modes** : Defines the number of modes in the photonic circuit, analogous to the width of a data bus in classical computing. Photons propagate through linear optical components (e.g., phase shifters and beamsplitters).
#
# - **n_photons** :
#   Number of photons injected into the circuit. The expressiveness of the quantum layer grows exponentially with this parameter, as it directly determines the dimensionality of the output space—specifically, the number of possible Fock states (photon number distributions across modes).
#
# - **b_no_bunching** :
#   Enforces the constraint that at most one photon is detected per mode (output channel). This simplifies computation by excluding photon bunching cases. It is a valid approximation when the number of photons squared (**n_photons^2**) is significantly smaller than the number of modes (n_modes), ensuring that the probability of bunching remains negligible
#
# ---
#
# #### Reproducibility
# - **seed** :
#   Controls the reproducibility of the experiment by fixing random number generators for Python, NumPy, PyTorch, and CUDA. If negative, then RNGs are not seeded.
#
# ---
#
# #### Data
# - **dataset_name** :
#   Select the dataset among 'mnist' (digits), 'k-mnist' (Kuzushiji), or 'fashion-mnist' (clothing).
#
# - **fold_index** :
#   Indicates which fold of the dataset is used for validation during cross-validation.
#
# - **n_fold** :
#   Specifies the number of folds for cross-validation, determining how the dataset is split into training and validation sets.
#
# ---
#
# #### Training Parameters
# - **n_epochs** :
#   Sets the number of training epochs (full passes through the dataset).
#
# - **batch_size** :
#   Number of images processed simultaneously in each stochastic gradient descent iteration.
#
# - **learning_rate** :
#   Step size for parameter updates. Higher values speed up learning but may reduce stability, while lower values ensure stability but may slow convergence.
#
# The training parameters were selected to match those reported in the reference article.

# %% [markdown]
# ## 2. Librairies loading & logging configuration

# %%
import os
import sys
import time
import datetime as dt
import math
import random
import logging
from pathlib import Path

# Ensure notebook imports work regardless of launch directory.
cwd = Path.cwd().resolve()
if (cwd / "lib").exists() and (cwd / "configs").exists():
    project_root = cwd
elif (cwd / "papers" / "QORC" / "lib").exists():
    project_root = cwd / "papers" / "QORC"
else:
    project_root = cwd
    while project_root != project_root.parent and not (project_root / "runtime_lib").exists():
        project_root = project_root.parent
    if (project_root / "papers" / "QORC" / "lib").exists():
        project_root = project_root / "papers" / "QORC"

repo_root = project_root.parent.parent
for p in (repo_root, project_root):
    p_str = str(p)
    if p_str not in sys.path:
        sys.path.insert(0, p_str)

import numpy as np
from sklearn.decomposition import PCA
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

import perceval as pcvl
import merlin as ML

from lib.lib_datasets import (
    tensor_dataset,
    get_dataloader,
    split_fold_numpy,
    get_mnist_variant,
)
from lib.lib_learning import get_device, model_eval, model_fit
from runtime_lib.logging_utils import configure_logging
from merlin.measurement.strategies import MeasurementStrategy, ComputationSpace

##################################
# Activate logging
configure_logging("info")  # basic console logging before config is resolved
logger = logging.getLogger(__name__)

# Prepare output directory with timestamped run folder
timestamp = dt.datetime.now().strftime("%Y%m%d-%H%M%S")
base_out = Path(outdir)
run_dir = base_out / f"run_{timestamp}"
run_dir.mkdir(parents=True, exist_ok=True)

# Configure logging based on resolved config and add file handler in the run directory
configure_logging("info", run_dir / "run.log")

# %% [markdown]
# ## 3. MNIST Dataset loading

# %% [markdown]
# The _get_mnist_variant()_ function loads one of three datasets: MNIST, Kuzushiji-MNIST (KMNIST), or Fashion-MNIST. Use the argument dataset_name with values 'mnist', 'k-mnist', or 'fashion-mnist' to specify the desired dataset.

# %%
storage_device = torch.device("cpu")
compute_device = get_device(device_name)

run_seed = seed
if run_seed >= 0:
    # Seeding to control the random generators
    random.seed(run_seed)
    np.random.seed(run_seed)
    torch.manual_seed(seed=run_seed)
    torch.cuda.manual_seed_all(seed=run_seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

torch.use_deterministic_algorithms(mode=False)

logger.info(
    "Call to qorc_encoding_and_linear_training: n_photons={}, n_modes={}, run_seed={}, fold_index={}".format(
        n_photons, n_modes, run_seed, fold_index
    )
)
time_t1 = time.time()

logger.info("Loading MNIST-variant data ({})".format(dataset_name))
val_train_data, val_train_label, test_data, test_label = get_mnist_variant(
    dataset_name
)

val_train_data = (
    val_train_data.reshape(val_train_data.shape[0], -1).astype(np.float32) / 255.0
)

val_label, val_data, train_label, train_data = split_fold_numpy(
    val_train_label, val_train_data, n_fold, fold_index, split_seed=run_seed
)

test_data = test_data.reshape(test_data.shape[0], -1).astype(np.float32) / 255.0
n_pixels = 28 * 28  # MNIST images size
n_classes = 10  # 10 classes, one for each figure

logger.info("Datasets sizes:")
logger.info(train_label.shape)  # (48000,)
logger.info(train_data.shape)  # (48000, 784)
logger.info(val_label.shape)  # (12000,)
logger.info(val_data.shape)  # (12000, 784)
logger.info(test_label.shape)  # (10000,)
logger.info(test_data.shape)  # (10000, 784)

# Display the first 5 images from the training set
plt.figure(figsize=(12, 3))  # Width x Height in inches
for i in range(5):
    # Reshape flattened data (784,) into a 28x28 image
    image = train_data[i].reshape(28, 28)
    plt.subplot(1, 5, i + 1)  # 1 row, 5 columns, position i+1
    plt.imshow(image, cmap='gray')
    plt.title(f"Label: {train_label[i]}")
    plt.axis('off')  # Hide axes
plt.tight_layout()  # Adjust spacing between images
plt.show()
# Out:
# 2026-07-16 00:20:46 | INFO | __main__ | Call to qorc_encoding_and_linear_training: n_photons=3, n_modes=20, run_seed=42, fold_index=0
# 2026-07-16 00:20:46 | INFO | __main__ | Loading MNIST-variant data (mnist)
# 2026-07-16 00:20:46 | INFO | __main__ | Datasets sizes:
# 2026-07-16 00:20:46 | INFO | __main__ | (48000,)
# 2026-07-16 00:20:46 | INFO | __main__ | (48000, 784)
# 2026-07-16 00:20:46 | INFO | __main__ | (12000,)
# 2026-07-16 00:20:46 | INFO | __main__ | (12000, 784)
# 2026-07-16 00:20:46 | INFO | __main__ | (10000,)
# 2026-07-16 00:20:46 | INFO | __main__ | (10000, 784)

# %% [markdown]
# ## 4. Definition of the Quantum Circuit and the Quantum Layer

# %% [markdown]
# ### Quantum Circuit
#
# In the QORC experiment, the architecture comprises a pre-circuit—an M-mode random Haar-uniform interferometer with N single-photon inputs—that generates a high-dimensional photonic resource state by distributing the photons across the modes. This state is then modulated by a column of phase shifters, which encode the classical input data (e.g., PCA-transformed features) into the quantum circuit by adjusting the optical phases. The processed state is further transformed by a reservoir, implemented as a second M-mode random interferometer (often identical to the pre-circuit), which enhances the non-linearity of the quantum features. The final output, a distribution over Fock states, serves as a highly expressive feature vector for subsequent classical processing, such as linear classification. The combination of the pre-circuit, phase shifters, and reservoir enables the mapping of input data into a complex quantum feature space, where the dimensionality scales combinatorially with the number of photons and modes, offering a potential advantage over classical feature extraction methods.

# %%
unitary = pcvl.Matrix.random_unitary(n_modes)  # Haar-uniform unitary sampling
precircuit = pcvl.Unitary(unitary)
reservoir = precircuit.copy()

# Input Phase Shifters
c_var = pcvl.Circuit(n_modes)
for i in range(n_modes):
    px = pcvl.P(f"px{i + 1}")
    port_range = i
    c_var.add(port_range, pcvl.PS(px))

qorc_circuit = precircuit // c_var // reservoir

# %% [markdown]
# ### Quantum Layer
# The input data is encoded into the phase parameters of the intermediate phase shifters, modulating the optical modes of the photonic circuit. The quantum layer's output consists of Fock-state probabilities (ML.OutputMappingStrategy.NONE), measured via coincidence detection at the circuit's output ports. These probabilities form a high-dimensional, non-linear feature vector, which is then used as input for classical classification tasks.

# %%
assert n_photons <= n_modes, (
    "Error with photons_input_mode: Too many photons versus modes."
)
step = (n_modes - 1) / (n_photons - 1) if n_photons > 1 else 0
qorc_input_state = [0] * n_modes
for k in range(n_photons):
    index = int(round(k * step))
    qorc_input_state[index] = 1

params_prefix = ["px"]

if b_no_bunching:
    qorc_output_size = math.comb(n_modes, n_photons)
    computation_space = ComputationSpace.UNBUNCHED
else:
    qorc_output_size = math.comb(n_photons + n_modes - 1, n_photons)
    computation_space = ComputationSpace.FOCK

logger.info("MerLin QuantumLayer creation:")
qorc_quantum_layer = ML.QuantumLayer(
    input_size=n_modes,  # Nb input features = nb modes
    circuit=qorc_circuit,  # QORC quantum circuit
    trainable_parameters=[],  # Circuit is not trainable
    input_parameters=params_prefix,  # Input encoding parameters
    input_state=qorc_input_state,  # Initial photon state
    measurement_strategy=MeasurementStrategy.probs(computation_space=computation_space),
    # See: https://merlinquantum.ai/user_guide/output_mappings.html
    device=torch.device(device_name),
)
logger.info(str(qorc_quantum_layer))
# Out:
# 2026-07-16 00:20:46 | INFO | __main__ | MerLin QuantumLayer creation:
# 2026-07-16 00:20:46 | INFO | __main__ | QuantumLayer(custom_circuit, modes=20, input_size=20, output_size=1140)

# %% [markdown]
# ## 5. Quantum features computation
# First, **PCA (Principal Component Analysis)** is applied to reduce the dimensionality of the input data, matching it to the number of modes in the quantum circuit. The resulting PCA components are then normalized using a **global min-max scaling**, ensuring compatibility with the phase shifters in the MerLin framework, which require bounded input values (to the range [0, 1]). After encoding the normalized data with the quantm layer, the output Fock-state probabilities are further standardized using a **StandardScaler**. This final normalization step improves the convergence and performance of the subsequent **linear classification layer**.

# %%
logger.info("Creation of the encoder of the quantum reservoir...")

# 1) PCA Components computation
pca = PCA(n_components=n_modes)
train_data_pca = pca.fit_transform(train_data)
val_data_pca = pca.transform(val_data)
test_data_pca = pca.transform(test_data)

# 2) PCA comp normalization (to [0, 1] (global min/max) )
pca_train_global_min = train_data_pca.min()
pca_train_global_max = train_data_pca.max()

def normalize_global_min_max(data, global_min, global_max):
    epsilon = 1e-8  # Avoid zero division
    return (data - global_min) / (global_max - global_min + epsilon)

train_data_pca_norm = normalize_global_min_max(
    train_data_pca, pca_train_global_min, pca_train_global_max
)
val_data_pca_norm = normalize_global_min_max(
    val_data_pca, pca_train_global_min, pca_train_global_max
)
test_data_pca_norm = normalize_global_min_max(
    test_data_pca, pca_train_global_min, pca_train_global_max
)

logger.info("Quantum features size: {}".format(qorc_output_size))
logger.info("Encoding of the PCA comps to quantum features...")
time_t2 = time.time()
train_data_qorc = qorc_quantum_layer(
    torch.tensor(train_data_pca_norm, dtype=torch.float32, device=compute_device)
)
val_data_qorc = qorc_quantum_layer(
    torch.tensor(val_data_pca_norm, dtype=torch.float32, device=compute_device)
)
test_data_qorc = qorc_quantum_layer(
    torch.tensor(test_data_pca_norm, dtype=torch.float32, device=compute_device)
)
logger.info("Encoding over.")
time_t3 = time.time()

# 4) Quantum features normalization (standard_scaler)
qorc_train_mean = train_data_qorc.detach().mean(dim=0)
qorc_train_std = train_data_qorc.detach().std(dim=0)

def normalize_standard_scaler(data, mean, std):
    epsilon = 1e-8  # Avoid zero division
    return (data - mean) / (std + epsilon)

train_data_qorc_norm = normalize_standard_scaler(
    train_data_qorc, qorc_train_mean, qorc_train_std
)
val_data_qorc_norm = normalize_standard_scaler(
    val_data_qorc, qorc_train_mean, qorc_train_std
)
test_data_qorc_norm = normalize_standard_scaler(
    test_data_qorc, qorc_train_mean, qorc_train_std
)
# Out:
# 2026-07-16 00:20:46 | INFO | __main__ | Creation of the encoder of the quantum reservoir...
# 2026-07-16 00:20:47 | INFO | __main__ | Quantum features size: 1140
# 2026-07-16 00:20:47 | INFO | __main__ | Encoding of the PCA comps to quantum features...
# 2026-07-16 00:20:50 | INFO | __main__ | Encoding over.

# %% [markdown]
# ## 6. Datasets and dataloader preparation for training

# %% [markdown]
# The input of the linear layer is the concatenation of the MNIST images and the quantum features.

# %%
dtype = torch.float32
all_train_data = torch.cat(
    (
        torch.tensor(train_data, dtype=dtype, device=compute_device),
        train_data_qorc_norm,
    ),
    dim=1,
)
all_val_data = torch.cat(
    (
        torch.tensor(val_data, dtype=dtype, device=compute_device),
        val_data_qorc_norm,
    ),
    dim=1,
)
all_test_data = torch.cat(
    (
        torch.tensor(test_data, dtype=dtype, device=compute_device),
        test_data_qorc_norm,
    ),
    dim=1,
)

# Datasets
ds_train = tensor_dataset(
    all_train_data,
    train_label,
    storage_device,
    dtype=torch.float32,
    transform=None,
    n_side_pixels=28,
)
ds_val = tensor_dataset(
    all_val_data, val_label, storage_device, dtype=torch.float32
)
ds_test = tensor_dataset(
    all_test_data, test_label, storage_device, dtype=torch.float32
)

logger.info("train dataset len: {}".format(len(ds_train)))
logger.info("val dataset len  : {}".format(len(ds_val)))
logger.info("test dataset len : {}".format(len(ds_test)))

# Dataloaders
shuffle_train = True
shuffle_test = False
train_loader = get_dataloader(
    ds_train, batch_size, shuffle_train, num_workers, pin_memory, run_seed
)
val_loader = get_dataloader(
    ds_val, batch_size, shuffle_test, num_workers, pin_memory, run_seed
)
test_loader = get_dataloader(
    ds_test, batch_size, shuffle_test, num_workers, pin_memory, run_seed
)

logger.info("train loader len: {}".format(len(train_loader)))
logger.info("val loader len  : {}".format(len(val_loader)))
logger.info("test loader len : {}".format(len(test_loader)))
# Out:
# 2026-07-16 00:20:50 | INFO | __main__ | train dataset len: 48000
# 2026-07-16 00:20:50 | INFO | __main__ | val dataset len  : 12000
# 2026-07-16 00:20:50 | INFO | __main__ | test dataset len : 10000
# 2026-07-16 00:20:50 | INFO | __main__ | train loader len: 480
# 2026-07-16 00:20:50 | INFO | __main__ | val loader len  : 120
# 2026-07-16 00:20:50 | INFO | __main__ | test loader len : 100

# %% [markdown]
# ## 7. Model Definition: Linear Classifier

# %% [markdown]
# The trained model consists of a standard PyTorch linear layer (nn.Linear), used to evaluate the quality of the quantum features by measuring the test accuracy. This simple classifier demonstrates how effectively the quantum reservoir transforms the input data into discriminative features.

# %%
logger.info("Prepare the linear classifier")

n_model_input_features = n_pixels + qorc_output_size
logger.info("n_model_input_features: {}".format(n_model_input_features))
linear = nn.Linear(
    n_model_input_features, n_classes, bias=True, device=compute_device
)

nn.init.xavier_uniform_(linear.weight)  # Xavier uniforme init (Glorot)
nn.init.zeros_(linear.bias)
model = linear
model.to(compute_device)
model.train()
torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

criterion = nn.CrossEntropyLoss(reduction="sum")
# Out:
# 2026-07-16 00:20:50 | INFO | __main__ | Prepare the linear classifier
# 2026-07-16 00:20:50 | INFO | __main__ | n_model_input_features: 1924

# %% [markdown]
# ## 8. Launching the Training Process

# %% [markdown]
# Following the reference article, the AdaGrad optimizer is used for training. The validation set is exclusively used for model selection based on the lowest validation loss. Consequently, no early stopping strategy is applied in this experiment.

# %%
logger.info("Evaluation before training (on test set)")
calc_accuracy = True
printPerf = True
_eval_test = model_eval(
    model, test_loader, criterion, compute_device, logger, calc_accuracy, printPerf
)

logger.info("Beginning of training")
optimizer = torch.optim.Adagrad(model.parameters(), lr=learning_rate, eps=1e-7)

if b_use_tensorboard:
    from torch.utils.tensorboard import SummaryWriter

    xp_name = (
        str(n_photons)
        + "photons_"
        + str(n_modes)
        + "modes_"
        + str(run_seed)
        + "seed_"
        + str(fold_index)
        + "fold"
    )
    tf_train_writer = SummaryWriter(
        os.path.join(run_dir, "runs/" + xp_name + "_train")
    )
    tf_val_writer = SummaryWriter(os.path.join(run_dir, "runs/" + xp_name + "_val"))
else:
    tf_train_writer = None
    tf_val_writer = None

early_stop_patience = n_epochs
early_stop_min_delta = 0.000001
b_use_cosine_scheduler = False
[
    train_loss_history,
    train_accuracy_history,
    val_loss_history,
    val_accuracy_history,
    duree_totale,
    best_val_epoch,
] = model_fit(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    n_epochs,
    os.path.join(run_dir, f_out_weights),
    early_stop_patience,
    early_stop_min_delta,
    reduce_lr_patience,
    reduce_lr_factor,
    compute_device,
    logger,
    b_use_cosine_scheduler,
    tf_train_writer=tf_train_writer,
    tf_val_writer=tf_val_writer,
    calc_accuracy=calc_accuracy,
)

logger.info("Training over.")
n_train_epochs = len(train_loss_history)
time_t4 = time.time()
# Out:
# 2026-07-16 00:20:50 | INFO | __main__ | Evaluation before training (on test set)
# 2026-07-16 00:20:50 | INFO | __main__ | 100/100 - 0s - loss: 2.8809 - accuracy: 0.0626
# 2026-07-16 00:20:50 | INFO | __main__ | Beginning of training
# 2026-07-16 00:20:50 | INFO | __main__ | Call model_fit(), with 19250 parameters to train.
# 2026-07-16 00:20:50 | INFO | __main__ | tag heure: 2026-07-16_00:20:50 (1784128850.8512688)
# 2026-07-16 00:20:51 | INFO | __main__ | Epoch 1/100
# 2026-07-16 00:20:51 | INFO | __main__ | 480/480 - 0s - loss: 0.4633 - accuracy: 0.8973 - val_loss: 0.2350 - val_accuracy: 0.9308
# 2026-07-16 00:20:51 | INFO | __main__ | Epoch 00001: val_loss improved from inf to 0.23498, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:20:51 | INFO | __main__ | tag heure: 2026-07-16_00:20:51 (1784128851.4347696)
# 2026-07-16 00:20:51 | INFO | __main__ | Epoch 2/100
# 2026-07-16 00:20:51 | INFO | __main__ | 480/480 - 0s - loss: 0.2091 - accuracy: 0.9394 - val_loss: 0.2029 - val_accuracy: 0.9405
# 2026-07-16 00:20:52 | INFO | __main__ | Epoch 00002: val_loss improved from 0.23498 to 0.20287, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:20:52 | INFO | __main__ | tag heure: 2026-07-16_00:20:52 (1784128852.0012608)
# 2026-07-16 00:20:52 | INFO | __main__ | Epoch 3/100
# 2026-07-16 00:20:52 | INFO | __main__ | 480/480 - 0s - loss: 0.1776 - accuracy: 0.9478 - val_loss: 0.1838 - val_accuracy: 0.9463
# 2026-07-16 00:20:52 | INFO | __main__ | Epoch 00003: val_loss improved from 0.20287 to 0.18383, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:20:52 | INFO | __main__ | tag heure: 2026-07-16_00:20:52 (1784128852.5809243)
# 2026-07-16 00:20:53 | INFO | __main__ | Epoch 4/100
# 2026-07-16 00:20:53 | INFO | __main__ | 480/480 - 0s - loss: 0.1638 - accuracy: 0.9513 - val_loss: 0.1662 - val_accuracy: 0.9512
# 2026-07-16 00:20:53 | INFO | __main__ | Epoch 00004: val_loss improved from 0.18383 to 0.16625, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:20:53 | INFO | __main__ | tag heure: 2026-07-16_00:20:53 (1784128853.1658194)
# 2026-07-16 00:20:53 | INFO | __main__ | Epoch 5/100
# 2026-07-16 00:20:53 | INFO | __main__ | 480/480 - 0s - loss: 0.1521 - accuracy: 0.9550 - val_loss: 0.1631 - val_accuracy: 0.9523
# 2026-07-16 00:20:53 | INFO | __main__ | Epoch 00005: val_loss improved from 0.16625 to 0.16313, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:20:53 | INFO | __main__ | tag heure: 2026-07-16_00:20:53 (1784128853.7804852)
# 2026-07-16 00:20:54 | INFO | __main__ | Epoch 6/100
# 2026-07-16 00:20:54 | INFO | __main__ | 480/480 - 0s - loss: 0.1441 - accuracy: 0.9576 - val_loss: 0.1624 - val_accuracy: 0.9512
# 2026-07-16 00:20:54 | INFO | __main__ | Epoch 00006: val_loss improved from 0.16313 to 0.16236, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:20:54 | INFO | __main__ | tag heure: 2026-07-16_00:20:54 (1784128854.3756127)
# 2026-07-16 00:20:55 | INFO | __main__ | Epoch 7/100
# 2026-07-16 00:20:55 | INFO | __main__ | 480/480 - 0s - loss: 0.1384 - accuracy: 0.9590 - val_loss: 0.1522 - val_accuracy: 0.9539
# 2026-07-16 00:20:55 | INFO | __main__ | Epoch 00007: val_loss improved from 0.16236 to 0.15220, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:20:55 | INFO | __main__ | tag heure: 2026-07-16_00:20:55 (1784128855.029634)
# 2026-07-16 00:20:55 | INFO | __main__ | Epoch 8/100
# 2026-07-16 00:20:55 | INFO | __main__ | 480/480 - 0s - loss: 0.1330 - accuracy: 0.9601 - val_loss: 0.1500 - val_accuracy: 0.9550
# 2026-07-16 00:20:55 | INFO | __main__ | Epoch 00008: val_loss improved from 0.15220 to 0.14997, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:20:55 | INFO | __main__ | tag heure: 2026-07-16_00:20:55 (1784128855.646715)
# 2026-07-16 00:20:56 | INFO | __main__ | Epoch 9/100
# 2026-07-16 00:20:56 | INFO | __main__ | 480/480 - 0s - loss: 0.1296 - accuracy: 0.9610 - val_loss: 0.1465 - val_accuracy: 0.9554
# 2026-07-16 00:20:56 | INFO | __main__ | Epoch 00009: val_loss improved from 0.14997 to 0.14653, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:20:56 | INFO | __main__ | tag heure: 2026-07-16_00:20:56 (1784128856.2549121)
# 2026-07-16 00:20:56 | INFO | __main__ | Epoch 10/100
# 2026-07-16 00:20:56 | INFO | __main__ | 480/480 - 0s - loss: 0.1259 - accuracy: 0.9630 - val_loss: 0.1444 - val_accuracy: 0.9559
# 2026-07-16 00:20:56 | INFO | __main__ | Epoch 00010: val_loss improved from 0.14653 to 0.14437, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:20:56 | INFO | __main__ | tag heure: 2026-07-16_00:20:56 (1784128856.9158921)
# 2026-07-16 00:20:57 | INFO | __main__ | Epoch 11/100
# 2026-07-16 00:20:57 | INFO | __main__ | 480/480 - 0s - loss: 0.1227 - accuracy: 0.9636 - val_loss: 0.1413 - val_accuracy: 0.9583
# 2026-07-16 00:20:57 | INFO | __main__ | Epoch 00011: val_loss improved from 0.14437 to 0.14132, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:20:57 | INFO | __main__ | tag heure: 2026-07-16_00:20:57 (1784128857.5026453)
# 2026-07-16 00:20:58 | INFO | __main__ | Epoch 12/100
# 2026-07-16 00:20:58 | INFO | __main__ | 480/480 - 0s - loss: 0.1208 - accuracy: 0.9644 - val_loss: 0.1390 - val_accuracy: 0.9571
# 2026-07-16 00:20:58 | INFO | __main__ | Epoch 00012: val_loss improved from 0.14132 to 0.13896, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:20:58 | INFO | __main__ | tag heure: 2026-07-16_00:20:58 (1784128858.1731825)
# 2026-07-16 00:20:58 | INFO | __main__ | Epoch 13/100
# 2026-07-16 00:20:58 | INFO | __main__ | 480/480 - 0s - loss: 0.1176 - accuracy: 0.9656 - val_loss: 0.1426 - val_accuracy: 0.9573
# 2026-07-16 00:20:58 | INFO | __main__ | Epoch 00013: val_loss did not improve from 0.13896
# 2026-07-16 00:20:58 | INFO | __main__ | tag heure: 2026-07-16_00:20:58 (1784128858.8647468)
# 2026-07-16 00:20:59 | INFO | __main__ | Epoch 14/100
# 2026-07-16 00:20:59 | INFO | __main__ | 480/480 - 0s - loss: 0.1160 - accuracy: 0.9659 - val_loss: 0.1363 - val_accuracy: 0.9587
# 2026-07-16 00:20:59 | INFO | __main__ | Epoch 00014: val_loss improved from 0.13896 to 0.13633, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:20:59 | INFO | __main__ | tag heure: 2026-07-16_00:20:59 (1784128859.5389414)
# 2026-07-16 00:21:00 | INFO | __main__ | Epoch 15/100
# 2026-07-16 00:21:00 | INFO | __main__ | 480/480 - 0s - loss: 0.1130 - accuracy: 0.9671 - val_loss: 0.1363 - val_accuracy: 0.9588
# 2026-07-16 00:21:00 | INFO | __main__ | Epoch 00015: val_loss did not improve from 0.13633
# 2026-07-16 00:21:00 | INFO | __main__ | tag heure: 2026-07-16_00:21:00 (1784128860.1652322)
# 2026-07-16 00:21:00 | INFO | __main__ | Epoch 16/100
# 2026-07-16 00:21:00 | INFO | __main__ | 480/480 - 0s - loss: 0.1117 - accuracy: 0.9673 - val_loss: 0.1359 - val_accuracy: 0.9584
# 2026-07-16 00:21:00 | INFO | __main__ | Epoch 00016: val_loss improved from 0.13633 to 0.13592, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:00 | INFO | __main__ | tag heure: 2026-07-16_00:21:00 (1784128860.807752)
# 2026-07-16 00:21:01 | INFO | __main__ | Epoch 17/100
# 2026-07-16 00:21:01 | INFO | __main__ | 480/480 - 0s - loss: 0.1099 - accuracy: 0.9676 - val_loss: 0.1355 - val_accuracy: 0.9592
# 2026-07-16 00:21:01 | INFO | __main__ | Epoch 00017: val_loss improved from 0.13592 to 0.13551, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:01 | INFO | __main__ | tag heure: 2026-07-16_00:21:01 (1784128861.5876846)
# 2026-07-16 00:21:02 | INFO | __main__ | Epoch 18/100
# 2026-07-16 00:21:02 | INFO | __main__ | 480/480 - 0s - loss: 0.1082 - accuracy: 0.9690 - val_loss: 0.1340 - val_accuracy: 0.9601
# 2026-07-16 00:21:02 | INFO | __main__ | Epoch 00018: val_loss improved from 0.13551 to 0.13395, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:02 | INFO | __main__ | tag heure: 2026-07-16_00:21:02 (1784128862.192993)
# 2026-07-16 00:21:02 | INFO | __main__ | Epoch 19/100
# 2026-07-16 00:21:02 | INFO | __main__ | 480/480 - 0s - loss: 0.1071 - accuracy: 0.9686 - val_loss: 0.1334 - val_accuracy: 0.9606
# 2026-07-16 00:21:02 | INFO | __main__ | Epoch 00019: val_loss improved from 0.13395 to 0.13341, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:02 | INFO | __main__ | tag heure: 2026-07-16_00:21:02 (1784128862.8531487)
# 2026-07-16 00:21:03 | INFO | __main__ | Epoch 20/100
# 2026-07-16 00:21:03 | INFO | __main__ | 480/480 - 0s - loss: 0.1055 - accuracy: 0.9688 - val_loss: 0.1302 - val_accuracy: 0.9602
# 2026-07-16 00:21:03 | INFO | __main__ | Epoch 00020: val_loss improved from 0.13341 to 0.13024, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:03 | INFO | __main__ | tag heure: 2026-07-16_00:21:03 (1784128863.4998424)
# 2026-07-16 00:21:04 | INFO | __main__ | Epoch 21/100
# 2026-07-16 00:21:04 | INFO | __main__ | 480/480 - 0s - loss: 0.1047 - accuracy: 0.9693 - val_loss: 0.1322 - val_accuracy: 0.9600
# 2026-07-16 00:21:04 | INFO | __main__ | Epoch 00021: val_loss did not improve from 0.13024
# 2026-07-16 00:21:04 | INFO | __main__ | tag heure: 2026-07-16_00:21:04 (1784128864.089548)
# 2026-07-16 00:21:04 | INFO | __main__ | Epoch 22/100
# 2026-07-16 00:21:04 | INFO | __main__ | 480/480 - 0s - loss: 0.1032 - accuracy: 0.9694 - val_loss: 0.1328 - val_accuracy: 0.9586
# 2026-07-16 00:21:04 | INFO | __main__ | Epoch 00022: val_loss did not improve from 0.13024
# 2026-07-16 00:21:04 | INFO | __main__ | tag heure: 2026-07-16_00:21:04 (1784128864.6955738)
# 2026-07-16 00:21:05 | INFO | __main__ | Epoch 23/100
# 2026-07-16 00:21:05 | INFO | __main__ | 480/480 - 0s - loss: 0.1023 - accuracy: 0.9699 - val_loss: 0.1318 - val_accuracy: 0.9602
# 2026-07-16 00:21:05 | INFO | __main__ | Epoch 00023: val_loss did not improve from 0.13024
# 2026-07-16 00:21:05 | INFO | __main__ | tag heure: 2026-07-16_00:21:05 (1784128865.3047411)
# 2026-07-16 00:21:05 | INFO | __main__ | Epoch 24/100
# 2026-07-16 00:21:05 | INFO | __main__ | 480/480 - 0s - loss: 0.1014 - accuracy: 0.9703 - val_loss: 0.1308 - val_accuracy: 0.9596
# 2026-07-16 00:21:05 | INFO | __main__ | Epoch 00024: val_loss did not improve from 0.13024
# 2026-07-16 00:21:05 | INFO | __main__ | tag heure: 2026-07-16_00:21:05 (1784128865.8996947)
# 2026-07-16 00:21:06 | INFO | __main__ | Epoch 25/100
# 2026-07-16 00:21:06 | INFO | __main__ | 480/480 - 0s - loss: 0.1001 - accuracy: 0.9704 - val_loss: 0.1300 - val_accuracy: 0.9597
# 2026-07-16 00:21:06 | INFO | __main__ | Epoch 00025: val_loss improved from 0.13024 to 0.13002, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:06 | INFO | __main__ | tag heure: 2026-07-16_00:21:06 (1784128866.502697)
# 2026-07-16 00:21:07 | INFO | __main__ | Epoch 26/100
# 2026-07-16 00:21:07 | INFO | __main__ | 480/480 - 0s - loss: 0.0996 - accuracy: 0.9709 - val_loss: 0.1280 - val_accuracy: 0.9622
# 2026-07-16 00:21:07 | INFO | __main__ | Epoch 00026: val_loss improved from 0.13002 to 0.12799, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:07 | INFO | __main__ | tag heure: 2026-07-16_00:21:07 (1784128867.099134)
# 2026-07-16 00:21:07 | INFO | __main__ | Epoch 27/100
# 2026-07-16 00:21:07 | INFO | __main__ | 480/480 - 0s - loss: 0.0983 - accuracy: 0.9709 - val_loss: 0.1280 - val_accuracy: 0.9610
# 2026-07-16 00:21:07 | INFO | __main__ | Epoch 00027: val_loss improved from 0.12799 to 0.12797, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:07 | INFO | __main__ | tag heure: 2026-07-16_00:21:07 (1784128867.7039504)
# 2026-07-16 00:21:08 | INFO | __main__ | Epoch 28/100
# 2026-07-16 00:21:08 | INFO | __main__ | 480/480 - 0s - loss: 0.0975 - accuracy: 0.9719 - val_loss: 0.1296 - val_accuracy: 0.9609
# 2026-07-16 00:21:08 | INFO | __main__ | Epoch 00028: val_loss did not improve from 0.12797
# 2026-07-16 00:21:08 | INFO | __main__ | tag heure: 2026-07-16_00:21:08 (1784128868.2683427)
# 2026-07-16 00:21:08 | INFO | __main__ | Epoch 29/100
# 2026-07-16 00:21:08 | INFO | __main__ | 480/480 - 0s - loss: 0.0966 - accuracy: 0.9724 - val_loss: 0.1269 - val_accuracy: 0.9609
# 2026-07-16 00:21:08 | INFO | __main__ | Epoch 00029: val_loss improved from 0.12797 to 0.12688, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:08 | INFO | __main__ | tag heure: 2026-07-16_00:21:08 (1784128868.8842695)
# 2026-07-16 00:21:09 | INFO | __main__ | Epoch 30/100
# 2026-07-16 00:21:09 | INFO | __main__ | 480/480 - 0s - loss: 0.0957 - accuracy: 0.9721 - val_loss: 0.1271 - val_accuracy: 0.9609
# 2026-07-16 00:21:09 | INFO | __main__ | Epoch 00030: val_loss did not improve from 0.12688
# 2026-07-16 00:21:09 | INFO | __main__ | tag heure: 2026-07-16_00:21:09 (1784128869.481384)
# 2026-07-16 00:21:10 | INFO | __main__ | Epoch 31/100
# 2026-07-16 00:21:10 | INFO | __main__ | 480/480 - 0s - loss: 0.0948 - accuracy: 0.9728 - val_loss: 0.1283 - val_accuracy: 0.9611
# 2026-07-16 00:21:10 | INFO | __main__ | Epoch 00031: val_loss did not improve from 0.12688
# 2026-07-16 00:21:10 | INFO | __main__ | tag heure: 2026-07-16_00:21:10 (1784128870.1005545)
# 2026-07-16 00:21:10 | INFO | __main__ | Epoch 32/100
# 2026-07-16 00:21:10 | INFO | __main__ | 480/480 - 0s - loss: 0.0948 - accuracy: 0.9719 - val_loss: 0.1246 - val_accuracy: 0.9625
# 2026-07-16 00:21:10 | INFO | __main__ | Epoch 00032: val_loss improved from 0.12688 to 0.12457, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:10 | INFO | __main__ | tag heure: 2026-07-16_00:21:10 (1784128870.7055824)
# 2026-07-16 00:21:11 | INFO | __main__ | Epoch 33/100
# 2026-07-16 00:21:11 | INFO | __main__ | 480/480 - 0s - loss: 0.0934 - accuracy: 0.9728 - val_loss: 0.1252 - val_accuracy: 0.9617
# 2026-07-16 00:21:11 | INFO | __main__ | Epoch 00033: val_loss did not improve from 0.12457
# 2026-07-16 00:21:11 | INFO | __main__ | tag heure: 2026-07-16_00:21:11 (1784128871.328213)
# 2026-07-16 00:21:11 | INFO | __main__ | Epoch 34/100
# 2026-07-16 00:21:11 | INFO | __main__ | 480/480 - 0s - loss: 0.0928 - accuracy: 0.9732 - val_loss: 0.1268 - val_accuracy: 0.9613
# 2026-07-16 00:21:11 | INFO | __main__ | Epoch 00034: val_loss did not improve from 0.12457
# 2026-07-16 00:21:11 | INFO | __main__ | tag heure: 2026-07-16_00:21:11 (1784128871.9424062)
# 2026-07-16 00:21:12 | INFO | __main__ | Epoch 35/100
# 2026-07-16 00:21:12 | INFO | __main__ | 480/480 - 0s - loss: 0.0917 - accuracy: 0.9736 - val_loss: 0.1277 - val_accuracy: 0.9608
# 2026-07-16 00:21:12 | INFO | __main__ | Epoch 00035: val_loss did not improve from 0.12457
# 2026-07-16 00:21:12 | INFO | __main__ | tag heure: 2026-07-16_00:21:12 (1784128872.564314)
# 2026-07-16 00:21:13 | INFO | __main__ | Epoch 36/100
# 2026-07-16 00:21:13 | INFO | __main__ | 480/480 - 0s - loss: 0.0917 - accuracy: 0.9736 - val_loss: 0.1250 - val_accuracy: 0.9617
# 2026-07-16 00:21:13 | INFO | __main__ | Epoch 00036: val_loss did not improve from 0.12457
# 2026-07-16 00:21:13 | INFO | __main__ | tag heure: 2026-07-16_00:21:13 (1784128873.2022374)
# 2026-07-16 00:21:13 | INFO | __main__ | Epoch 37/100
# 2026-07-16 00:21:13 | INFO | __main__ | 480/480 - 0s - loss: 0.0911 - accuracy: 0.9734 - val_loss: 0.1265 - val_accuracy: 0.9607
# 2026-07-16 00:21:13 | INFO | __main__ | Epoch 00037: val_loss did not improve from 0.12457
# 2026-07-16 00:21:13 | INFO | __main__ | tag heure: 2026-07-16_00:21:13 (1784128873.9758556)
# 2026-07-16 00:21:14 | INFO | __main__ | Epoch 38/100
# 2026-07-16 00:21:14 | INFO | __main__ | 480/480 - 0s - loss: 0.0902 - accuracy: 0.9744 - val_loss: 0.1229 - val_accuracy: 0.9628
# 2026-07-16 00:21:14 | INFO | __main__ | Epoch 00038: val_loss improved from 0.12457 to 0.12288, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:14 | INFO | __main__ | tag heure: 2026-07-16_00:21:14 (1784128874.9351969)
# 2026-07-16 00:21:15 | INFO | __main__ | Epoch 39/100
# 2026-07-16 00:21:15 | INFO | __main__ | 480/480 - 0s - loss: 0.0897 - accuracy: 0.9740 - val_loss: 0.1239 - val_accuracy: 0.9613
# 2026-07-16 00:21:15 | INFO | __main__ | Epoch 00039: val_loss did not improve from 0.12288
# 2026-07-16 00:21:15 | INFO | __main__ | tag heure: 2026-07-16_00:21:15 (1784128875.7248363)
# 2026-07-16 00:21:16 | INFO | __main__ | Epoch 40/100
# 2026-07-16 00:21:16 | INFO | __main__ | 480/480 - 0s - loss: 0.0891 - accuracy: 0.9739 - val_loss: 0.1235 - val_accuracy: 0.9628
# 2026-07-16 00:21:16 | INFO | __main__ | Epoch 00040: val_loss did not improve from 0.12288
# 2026-07-16 00:21:16 | INFO | __main__ | tag heure: 2026-07-16_00:21:16 (1784128876.6159306)
# 2026-07-16 00:21:17 | INFO | __main__ | Epoch 41/100
# 2026-07-16 00:21:17 | INFO | __main__ | 480/480 - 0s - loss: 0.0888 - accuracy: 0.9743 - val_loss: 0.1241 - val_accuracy: 0.9619
# 2026-07-16 00:21:17 | INFO | __main__ | Epoch 00041: val_loss did not improve from 0.12288
# 2026-07-16 00:21:17 | INFO | __main__ | tag heure: 2026-07-16_00:21:17 (1784128877.3746343)
# 2026-07-16 00:21:18 | INFO | __main__ | Epoch 42/100
# 2026-07-16 00:21:18 | INFO | __main__ | 480/480 - 0s - loss: 0.0882 - accuracy: 0.9744 - val_loss: 0.1226 - val_accuracy: 0.9626
# 2026-07-16 00:21:18 | INFO | __main__ | Epoch 00042: val_loss improved from 0.12288 to 0.12264, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:18 | INFO | __main__ | tag heure: 2026-07-16_00:21:18 (1784128878.1513307)
# 2026-07-16 00:21:18 | INFO | __main__ | Epoch 43/100
# 2026-07-16 00:21:18 | INFO | __main__ | 480/480 - 0s - loss: 0.0876 - accuracy: 0.9745 - val_loss: 0.1225 - val_accuracy: 0.9627
# 2026-07-16 00:21:18 | INFO | __main__ | Epoch 00043: val_loss improved from 0.12264 to 0.12249, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:18 | INFO | __main__ | tag heure: 2026-07-16_00:21:18 (1784128878.9022534)
# 2026-07-16 00:21:19 | INFO | __main__ | Epoch 44/100
# 2026-07-16 00:21:19 | INFO | __main__ | 480/480 - 0s - loss: 0.0872 - accuracy: 0.9742 - val_loss: 0.1223 - val_accuracy: 0.9622
# 2026-07-16 00:21:19 | INFO | __main__ | Epoch 00044: val_loss improved from 0.12249 to 0.12225, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:19 | INFO | __main__ | tag heure: 2026-07-16_00:21:19 (1784128879.6981711)
# 2026-07-16 00:21:20 | INFO | __main__ | Epoch 45/100
# 2026-07-16 00:21:20 | INFO | __main__ | 480/480 - 0s - loss: 0.0866 - accuracy: 0.9748 - val_loss: 0.1202 - val_accuracy: 0.9628
# 2026-07-16 00:21:20 | INFO | __main__ | Epoch 00045: val_loss improved from 0.12225 to 0.12019, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:20 | INFO | __main__ | tag heure: 2026-07-16_00:21:20 (1784128880.4231179)
# 2026-07-16 00:21:21 | INFO | __main__ | Epoch 46/100
# 2026-07-16 00:21:21 | INFO | __main__ | 480/480 - 0s - loss: 0.0860 - accuracy: 0.9754 - val_loss: 0.1226 - val_accuracy: 0.9619
# 2026-07-16 00:21:21 | INFO | __main__ | Epoch 00046: val_loss did not improve from 0.12019
# 2026-07-16 00:21:21 | INFO | __main__ | tag heure: 2026-07-16_00:21:21 (1784128881.1434565)
# 2026-07-16 00:21:21 | INFO | __main__ | Epoch 47/100
# 2026-07-16 00:21:22 | INFO | __main__ | 480/480 - 0s - loss: 0.0854 - accuracy: 0.9755 - val_loss: 0.1223 - val_accuracy: 0.9614
# 2026-07-16 00:21:22 | INFO | __main__ | Epoch 00047: val_loss did not improve from 0.12019
# 2026-07-16 00:21:22 | INFO | __main__ | tag heure: 2026-07-16_00:21:22 (1784128882.0017703)
# 2026-07-16 00:21:22 | INFO | __main__ | Epoch 48/100
# 2026-07-16 00:21:22 | INFO | __main__ | 480/480 - 0s - loss: 0.0854 - accuracy: 0.9751 - val_loss: 0.1226 - val_accuracy: 0.9613
# 2026-07-16 00:21:22 | INFO | __main__ | Epoch 00048: val_loss did not improve from 0.12019
# 2026-07-16 00:21:22 | INFO | __main__ | tag heure: 2026-07-16_00:21:22 (1784128882.8646102)
# 2026-07-16 00:21:23 | INFO | __main__ | Epoch 49/100
# 2026-07-16 00:21:23 | INFO | __main__ | 480/480 - 0s - loss: 0.0848 - accuracy: 0.9761 - val_loss: 0.1194 - val_accuracy: 0.9635
# 2026-07-16 00:21:23 | INFO | __main__ | Epoch 00049: val_loss improved from 0.12019 to 0.11942, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:23 | INFO | __main__ | tag heure: 2026-07-16_00:21:23 (1784128883.6247835)
# 2026-07-16 00:21:24 | INFO | __main__ | Epoch 50/100
# 2026-07-16 00:21:24 | INFO | __main__ | 480/480 - 0s - loss: 0.0840 - accuracy: 0.9755 - val_loss: 0.1211 - val_accuracy: 0.9621
# 2026-07-16 00:21:24 | INFO | __main__ | Epoch 00050: val_loss did not improve from 0.11942
# 2026-07-16 00:21:24 | INFO | __main__ | tag heure: 2026-07-16_00:21:24 (1784128884.4050827)
# 2026-07-16 00:21:25 | INFO | __main__ | Epoch 51/100
# 2026-07-16 00:21:25 | INFO | __main__ | 480/480 - 0s - loss: 0.0840 - accuracy: 0.9756 - val_loss: 0.1202 - val_accuracy: 0.9628
# 2026-07-16 00:21:25 | INFO | __main__ | Epoch 00051: val_loss did not improve from 0.11942
# 2026-07-16 00:21:25 | INFO | __main__ | tag heure: 2026-07-16_00:21:25 (1784128885.1461358)
# 2026-07-16 00:21:25 | INFO | __main__ | Epoch 52/100
# 2026-07-16 00:21:25 | INFO | __main__ | 480/480 - 0s - loss: 0.0837 - accuracy: 0.9753 - val_loss: 0.1195 - val_accuracy: 0.9618
# 2026-07-16 00:21:25 | INFO | __main__ | Epoch 00052: val_loss did not improve from 0.11942
# 2026-07-16 00:21:25 | INFO | __main__ | tag heure: 2026-07-16_00:21:25 (1784128885.8914263)
# 2026-07-16 00:21:26 | INFO | __main__ | Epoch 53/100
# 2026-07-16 00:21:26 | INFO | __main__ | 480/480 - 0s - loss: 0.0830 - accuracy: 0.9760 - val_loss: 0.1208 - val_accuracy: 0.9628
# 2026-07-16 00:21:26 | INFO | __main__ | Epoch 00053: val_loss did not improve from 0.11942
# 2026-07-16 00:21:26 | INFO | __main__ | tag heure: 2026-07-16_00:21:26 (1784128886.6970124)
# 2026-07-16 00:21:27 | INFO | __main__ | Epoch 54/100
# 2026-07-16 00:21:27 | INFO | __main__ | 480/480 - 0s - loss: 0.0829 - accuracy: 0.9753 - val_loss: 0.1227 - val_accuracy: 0.9632
# 2026-07-16 00:21:27 | INFO | __main__ | Epoch 00054: val_loss did not improve from 0.11942
# 2026-07-16 00:21:27 | INFO | __main__ | tag heure: 2026-07-16_00:21:27 (1784128887.4532318)
# 2026-07-16 00:21:28 | INFO | __main__ | Epoch 55/100
# 2026-07-16 00:21:28 | INFO | __main__ | 480/480 - 0s - loss: 0.0823 - accuracy: 0.9765 - val_loss: 0.1229 - val_accuracy: 0.9619
# 2026-07-16 00:21:28 | INFO | __main__ | Epoch 00055: val_loss did not improve from 0.11942
# 2026-07-16 00:21:28 | INFO | __main__ | tag heure: 2026-07-16_00:21:28 (1784128888.209548)
# 2026-07-16 00:21:28 | INFO | __main__ | Epoch 56/100
# 2026-07-16 00:21:28 | INFO | __main__ | 480/480 - 0s - loss: 0.0819 - accuracy: 0.9762 - val_loss: 0.1218 - val_accuracy: 0.9610
# 2026-07-16 00:21:28 | INFO | __main__ | Epoch 00056: val_loss did not improve from 0.11942
# 2026-07-16 00:21:28 | INFO | __main__ | tag heure: 2026-07-16_00:21:28 (1784128888.9431329)
# 2026-07-16 00:21:29 | INFO | __main__ | Epoch 57/100
# 2026-07-16 00:21:29 | INFO | __main__ | 480/480 - 0s - loss: 0.0814 - accuracy: 0.9763 - val_loss: 0.1196 - val_accuracy: 0.9630
# 2026-07-16 00:21:29 | INFO | __main__ | Epoch 00057: val_loss did not improve from 0.11942
# 2026-07-16 00:21:29 | INFO | __main__ | tag heure: 2026-07-16_00:21:29 (1784128889.7196217)
# 2026-07-16 00:21:30 | INFO | __main__ | Epoch 58/100
# 2026-07-16 00:21:30 | INFO | __main__ | 480/480 - 0s - loss: 0.0813 - accuracy: 0.9761 - val_loss: 0.1201 - val_accuracy: 0.9617
# 2026-07-16 00:21:30 | INFO | __main__ | Epoch 00058: val_loss did not improve from 0.11942
# 2026-07-16 00:21:30 | INFO | __main__ | tag heure: 2026-07-16_00:21:30 (1784128890.4735823)
# 2026-07-16 00:21:31 | INFO | __main__ | Epoch 59/100
# 2026-07-16 00:21:31 | INFO | __main__ | 480/480 - 0s - loss: 0.0807 - accuracy: 0.9765 - val_loss: 0.1217 - val_accuracy: 0.9625
# 2026-07-16 00:21:31 | INFO | __main__ | Epoch 00059: val_loss did not improve from 0.11942
# 2026-07-16 00:21:31 | INFO | __main__ | Epoch 00059: ReduceLROnPlateau reducing learning rate to 2.500000e-02
# 2026-07-16 00:21:31 | INFO | __main__ | tag heure: 2026-07-16_00:21:31 (1784128891.2133276)
# 2026-07-16 00:21:31 | INFO | __main__ | Epoch 60/100
# 2026-07-16 00:21:31 | INFO | __main__ | 480/480 - 0s - loss: 0.0782 - accuracy: 0.9777 - val_loss: 0.1185 - val_accuracy: 0.9639
# 2026-07-16 00:21:31 | INFO | __main__ | Epoch 00060: val_loss improved from 0.11942 to 0.11850, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:31 | INFO | __main__ | tag heure: 2026-07-16_00:21:31 (1784128891.9655287)
# 2026-07-16 00:21:32 | INFO | __main__ | Epoch 61/100
# 2026-07-16 00:21:32 | INFO | __main__ | 480/480 - 0s - loss: 0.0779 - accuracy: 0.9777 - val_loss: 0.1179 - val_accuracy: 0.9640
# 2026-07-16 00:21:32 | INFO | __main__ | Epoch 00061: val_loss improved from 0.11850 to 0.11792, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:32 | INFO | __main__ | tag heure: 2026-07-16_00:21:32 (1784128892.695795)
# 2026-07-16 00:21:33 | INFO | __main__ | Epoch 62/100
# 2026-07-16 00:21:33 | INFO | __main__ | 480/480 - 0s - loss: 0.0776 - accuracy: 0.9777 - val_loss: 0.1178 - val_accuracy: 0.9628
# 2026-07-16 00:21:33 | INFO | __main__ | Epoch 00062: val_loss improved from 0.11792 to 0.11784, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:33 | INFO | __main__ | tag heure: 2026-07-16_00:21:33 (1784128893.4269974)
# 2026-07-16 00:21:34 | INFO | __main__ | Epoch 63/100
# 2026-07-16 00:21:34 | INFO | __main__ | 480/480 - 0s - loss: 0.0775 - accuracy: 0.9776 - val_loss: 0.1171 - val_accuracy: 0.9636
# 2026-07-16 00:21:34 | INFO | __main__ | Epoch 00063: val_loss improved from 0.11784 to 0.11707, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:34 | INFO | __main__ | tag heure: 2026-07-16_00:21:34 (1784128894.1354609)
# 2026-07-16 00:21:34 | INFO | __main__ | Epoch 64/100
# 2026-07-16 00:21:34 | INFO | __main__ | 480/480 - 0s - loss: 0.0773 - accuracy: 0.9781 - val_loss: 0.1177 - val_accuracy: 0.9628
# 2026-07-16 00:21:34 | INFO | __main__ | Epoch 00064: val_loss did not improve from 0.11707
# 2026-07-16 00:21:34 | INFO | __main__ | tag heure: 2026-07-16_00:21:34 (1784128894.8460007)
# 2026-07-16 00:21:35 | INFO | __main__ | Epoch 65/100
# 2026-07-16 00:21:35 | INFO | __main__ | 480/480 - 0s - loss: 0.0772 - accuracy: 0.9776 - val_loss: 0.1166 - val_accuracy: 0.9640
# 2026-07-16 00:21:35 | INFO | __main__ | Epoch 00065: val_loss improved from 0.11707 to 0.11661, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:35 | INFO | __main__ | tag heure: 2026-07-16_00:21:35 (1784128895.5550156)
# 2026-07-16 00:21:36 | INFO | __main__ | Epoch 66/100
# 2026-07-16 00:21:36 | INFO | __main__ | 480/480 - 0s - loss: 0.0768 - accuracy: 0.9781 - val_loss: 0.1170 - val_accuracy: 0.9633
# 2026-07-16 00:21:36 | INFO | __main__ | Epoch 00066: val_loss did not improve from 0.11661
# 2026-07-16 00:21:36 | INFO | __main__ | tag heure: 2026-07-16_00:21:36 (1784128896.2763429)
# 2026-07-16 00:21:37 | INFO | __main__ | Epoch 67/100
# 2026-07-16 00:21:37 | INFO | __main__ | 480/480 - 0s - loss: 0.0769 - accuracy: 0.9780 - val_loss: 0.1167 - val_accuracy: 0.9638
# 2026-07-16 00:21:37 | INFO | __main__ | Epoch 00067: val_loss did not improve from 0.11661
# 2026-07-16 00:21:37 | INFO | __main__ | tag heure: 2026-07-16_00:21:37 (1784128897.0709393)
# 2026-07-16 00:21:37 | INFO | __main__ | Epoch 68/100
# 2026-07-16 00:21:37 | INFO | __main__ | 480/480 - 0s - loss: 0.0767 - accuracy: 0.9779 - val_loss: 0.1158 - val_accuracy: 0.9637
# 2026-07-16 00:21:37 | INFO | __main__ | Epoch 00068: val_loss improved from 0.11661 to 0.11581, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:37 | INFO | __main__ | tag heure: 2026-07-16_00:21:37 (1784128897.7957573)
# 2026-07-16 00:21:38 | INFO | __main__ | Epoch 69/100
# 2026-07-16 00:21:38 | INFO | __main__ | 480/480 - 0s - loss: 0.0767 - accuracy: 0.9779 - val_loss: 0.1173 - val_accuracy: 0.9638
# 2026-07-16 00:21:38 | INFO | __main__ | Epoch 00069: val_loss did not improve from 0.11581
# 2026-07-16 00:21:38 | INFO | __main__ | tag heure: 2026-07-16_00:21:38 (1784128898.5628746)
# 2026-07-16 00:21:39 | INFO | __main__ | Epoch 70/100
# 2026-07-16 00:21:39 | INFO | __main__ | 480/480 - 0s - loss: 0.0762 - accuracy: 0.9784 - val_loss: 0.1173 - val_accuracy: 0.9632
# 2026-07-16 00:21:39 | INFO | __main__ | Epoch 00070: val_loss did not improve from 0.11581
# 2026-07-16 00:21:39 | INFO | __main__ | tag heure: 2026-07-16_00:21:39 (1784128899.2967472)
# 2026-07-16 00:21:39 | INFO | __main__ | Epoch 71/100
# 2026-07-16 00:21:39 | INFO | __main__ | 480/480 - 0s - loss: 0.0762 - accuracy: 0.9783 - val_loss: 0.1179 - val_accuracy: 0.9633
# 2026-07-16 00:21:39 | INFO | __main__ | Epoch 00071: val_loss did not improve from 0.11581
# 2026-07-16 00:21:39 | INFO | __main__ | tag heure: 2026-07-16_00:21:39 (1784128899.9932005)
# 2026-07-16 00:21:40 | INFO | __main__ | Epoch 72/100
# 2026-07-16 00:21:40 | INFO | __main__ | 480/480 - 0s - loss: 0.0763 - accuracy: 0.9778 - val_loss: 0.1176 - val_accuracy: 0.9639
# 2026-07-16 00:21:40 | INFO | __main__ | Epoch 00072: val_loss did not improve from 0.11581
# 2026-07-16 00:21:40 | INFO | __main__ | tag heure: 2026-07-16_00:21:40 (1784128900.7681477)
# 2026-07-16 00:21:41 | INFO | __main__ | Epoch 73/100
# 2026-07-16 00:21:41 | INFO | __main__ | 480/480 - 0s - loss: 0.0760 - accuracy: 0.9784 - val_loss: 0.1170 - val_accuracy: 0.9641
# 2026-07-16 00:21:41 | INFO | __main__ | Epoch 00073: val_loss did not improve from 0.11581
# 2026-07-16 00:21:41 | INFO | __main__ | tag heure: 2026-07-16_00:21:41 (1784128901.4997592)
# 2026-07-16 00:21:42 | INFO | __main__ | Epoch 74/100
# 2026-07-16 00:21:42 | INFO | __main__ | 480/480 - 0s - loss: 0.0759 - accuracy: 0.9785 - val_loss: 0.1169 - val_accuracy: 0.9632
# 2026-07-16 00:21:42 | INFO | __main__ | Epoch 00074: val_loss did not improve from 0.11581
# 2026-07-16 00:21:42 | INFO | __main__ | tag heure: 2026-07-16_00:21:42 (1784128902.2047987)
# 2026-07-16 00:21:42 | INFO | __main__ | Epoch 75/100
# 2026-07-16 00:21:42 | INFO | __main__ | 480/480 - 0s - loss: 0.0757 - accuracy: 0.9779 - val_loss: 0.1176 - val_accuracy: 0.9629
# 2026-07-16 00:21:42 | INFO | __main__ | Epoch 00075: val_loss did not improve from 0.11581
# 2026-07-16 00:21:42 | INFO | __main__ | tag heure: 2026-07-16_00:21:42 (1784128902.920255)
# 2026-07-16 00:21:43 | INFO | __main__ | Epoch 76/100
# 2026-07-16 00:21:43 | INFO | __main__ | 480/480 - 0s - loss: 0.0755 - accuracy: 0.9782 - val_loss: 0.1162 - val_accuracy: 0.9635
# 2026-07-16 00:21:43 | INFO | __main__ | Epoch 00076: val_loss did not improve from 0.11581
# 2026-07-16 00:21:43 | INFO | __main__ | tag heure: 2026-07-16_00:21:43 (1784128903.7860575)
# 2026-07-16 00:21:44 | INFO | __main__ | Epoch 77/100
# 2026-07-16 00:21:44 | INFO | __main__ | 480/480 - 0s - loss: 0.0756 - accuracy: 0.9782 - val_loss: 0.1175 - val_accuracy: 0.9630
# 2026-07-16 00:21:44 | INFO | __main__ | Epoch 00077: val_loss did not improve from 0.11581
# 2026-07-16 00:21:44 | INFO | __main__ | tag heure: 2026-07-16_00:21:44 (1784128904.6000354)
# 2026-07-16 00:21:45 | INFO | __main__ | Epoch 78/100
# 2026-07-16 00:21:45 | INFO | __main__ | 480/480 - 0s - loss: 0.0754 - accuracy: 0.9778 - val_loss: 0.1168 - val_accuracy: 0.9637
# 2026-07-16 00:21:45 | INFO | __main__ | Epoch 00078: val_loss did not improve from 0.11581
# 2026-07-16 00:21:45 | INFO | __main__ | Epoch 00078: ReduceLROnPlateau reducing learning rate to 1.250000e-02
# 2026-07-16 00:21:45 | INFO | __main__ | tag heure: 2026-07-16_00:21:45 (1784128905.3090503)
# 2026-07-16 00:21:46 | INFO | __main__ | Epoch 79/100
# 2026-07-16 00:21:46 | INFO | __main__ | 480/480 - 0s - loss: 0.0742 - accuracy: 0.9787 - val_loss: 0.1157 - val_accuracy: 0.9643
# 2026-07-16 00:21:46 | INFO | __main__ | Epoch 00079: val_loss improved from 0.11581 to 0.11572, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:46 | INFO | __main__ | tag heure: 2026-07-16_00:21:46 (1784128906.006224)
# 2026-07-16 00:21:46 | INFO | __main__ | Epoch 80/100
# 2026-07-16 00:21:46 | INFO | __main__ | 480/480 - 0s - loss: 0.0739 - accuracy: 0.9789 - val_loss: 0.1158 - val_accuracy: 0.9635
# 2026-07-16 00:21:46 | INFO | __main__ | Epoch 00080: val_loss did not improve from 0.11572
# 2026-07-16 00:21:46 | INFO | __main__ | tag heure: 2026-07-16_00:21:46 (1784128906.7303493)
# 2026-07-16 00:21:47 | INFO | __main__ | Epoch 81/100
# 2026-07-16 00:21:47 | INFO | __main__ | 480/480 - 0s - loss: 0.0738 - accuracy: 0.9787 - val_loss: 0.1160 - val_accuracy: 0.9646
# 2026-07-16 00:21:47 | INFO | __main__ | Epoch 00081: val_loss did not improve from 0.11572
# 2026-07-16 00:21:47 | INFO | __main__ | tag heure: 2026-07-16_00:21:47 (1784128907.469014)
# 2026-07-16 00:21:48 | INFO | __main__ | Epoch 82/100
# 2026-07-16 00:21:48 | INFO | __main__ | 480/480 - 0s - loss: 0.0739 - accuracy: 0.9788 - val_loss: 0.1162 - val_accuracy: 0.9641
# 2026-07-16 00:21:48 | INFO | __main__ | Epoch 00082: val_loss did not improve from 0.11572
# 2026-07-16 00:21:48 | INFO | __main__ | tag heure: 2026-07-16_00:21:48 (1784128908.2075613)
# 2026-07-16 00:21:48 | INFO | __main__ | Epoch 83/100
# 2026-07-16 00:21:48 | INFO | __main__ | 480/480 - 0s - loss: 0.0738 - accuracy: 0.9788 - val_loss: 0.1164 - val_accuracy: 0.9635
# 2026-07-16 00:21:48 | INFO | __main__ | Epoch 00083: val_loss did not improve from 0.11572
# 2026-07-16 00:21:48 | INFO | __main__ | tag heure: 2026-07-16_00:21:48 (1784128908.9145243)
# 2026-07-16 00:21:49 | INFO | __main__ | Epoch 84/100
# 2026-07-16 00:21:49 | INFO | __main__ | 480/480 - 0s - loss: 0.0737 - accuracy: 0.9790 - val_loss: 0.1159 - val_accuracy: 0.9641
# 2026-07-16 00:21:49 | INFO | __main__ | Epoch 00084: val_loss did not improve from 0.11572
# 2026-07-16 00:21:49 | INFO | __main__ | tag heure: 2026-07-16_00:21:49 (1784128909.6628265)
# 2026-07-16 00:21:50 | INFO | __main__ | Epoch 85/100
# 2026-07-16 00:21:50 | INFO | __main__ | 480/480 - 0s - loss: 0.0736 - accuracy: 0.9788 - val_loss: 0.1162 - val_accuracy: 0.9635
# 2026-07-16 00:21:50 | INFO | __main__ | Epoch 00085: val_loss did not improve from 0.11572
# 2026-07-16 00:21:50 | INFO | __main__ | tag heure: 2026-07-16_00:21:50 (1784128910.4099767)
# 2026-07-16 00:21:51 | INFO | __main__ | Epoch 86/100
# 2026-07-16 00:21:51 | INFO | __main__ | 480/480 - 0s - loss: 0.0735 - accuracy: 0.9789 - val_loss: 0.1161 - val_accuracy: 0.9630
# 2026-07-16 00:21:51 | INFO | __main__ | Epoch 00086: val_loss did not improve from 0.11572
# 2026-07-16 00:21:51 | INFO | __main__ | tag heure: 2026-07-16_00:21:51 (1784128911.143758)
# 2026-07-16 00:21:51 | INFO | __main__ | Epoch 87/100
# 2026-07-16 00:21:51 | INFO | __main__ | 480/480 - 0s - loss: 0.0735 - accuracy: 0.9794 - val_loss: 0.1163 - val_accuracy: 0.9643
# 2026-07-16 00:21:51 | INFO | __main__ | Epoch 00087: val_loss did not improve from 0.11572
# 2026-07-16 00:21:51 | INFO | __main__ | tag heure: 2026-07-16_00:21:51 (1784128911.8962307)
# 2026-07-16 00:21:52 | INFO | __main__ | Epoch 88/100
# 2026-07-16 00:21:52 | INFO | __main__ | 480/480 - 0s - loss: 0.0735 - accuracy: 0.9788 - val_loss: 0.1157 - val_accuracy: 0.9637
# 2026-07-16 00:21:52 | INFO | __main__ | Epoch 00088: val_loss did not improve from 0.11572
# 2026-07-16 00:21:52 | INFO | __main__ | tag heure: 2026-07-16_00:21:52 (1784128912.6330874)
# 2026-07-16 00:21:53 | INFO | __main__ | Epoch 89/100
# 2026-07-16 00:21:53 | INFO | __main__ | 480/480 - 0s - loss: 0.0734 - accuracy: 0.9793 - val_loss: 0.1158 - val_accuracy: 0.9640
# 2026-07-16 00:21:53 | INFO | __main__ | Epoch 00089: val_loss did not improve from 0.11572
# 2026-07-16 00:21:53 | INFO | __main__ | Epoch 00089: ReduceLROnPlateau reducing learning rate to 6.250000e-03
# 2026-07-16 00:21:53 | INFO | __main__ | tag heure: 2026-07-16_00:21:53 (1784128913.3616977)
# 2026-07-16 00:21:54 | INFO | __main__ | Epoch 90/100
# 2026-07-16 00:21:54 | INFO | __main__ | 480/480 - 0s - loss: 0.0728 - accuracy: 0.9790 - val_loss: 0.1158 - val_accuracy: 0.9639
# 2026-07-16 00:21:54 | INFO | __main__ | Epoch 00090: val_loss did not improve from 0.11572
# 2026-07-16 00:21:54 | INFO | __main__ | tag heure: 2026-07-16_00:21:54 (1784128914.0655274)
# 2026-07-16 00:21:54 | INFO | __main__ | Epoch 91/100
# 2026-07-16 00:21:54 | INFO | __main__ | 480/480 - 0s - loss: 0.0727 - accuracy: 0.9789 - val_loss: 0.1155 - val_accuracy: 0.9643
# 2026-07-16 00:21:54 | INFO | __main__ | Epoch 00091: val_loss improved from 0.11572 to 0.11551, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:54 | INFO | __main__ | tag heure: 2026-07-16_00:21:54 (1784128914.7723615)
# 2026-07-16 00:21:55 | INFO | __main__ | Epoch 92/100
# 2026-07-16 00:21:55 | INFO | __main__ | 480/480 - 0s - loss: 0.0727 - accuracy: 0.9789 - val_loss: 0.1156 - val_accuracy: 0.9642
# 2026-07-16 00:21:55 | INFO | __main__ | Epoch 00092: val_loss did not improve from 0.11551
# 2026-07-16 00:21:55 | INFO | __main__ | tag heure: 2026-07-16_00:21:55 (1784128915.5041666)
# 2026-07-16 00:21:56 | INFO | __main__ | Epoch 93/100
# 2026-07-16 00:21:56 | INFO | __main__ | 480/480 - 0s - loss: 0.0726 - accuracy: 0.9793 - val_loss: 0.1158 - val_accuracy: 0.9640
# 2026-07-16 00:21:56 | INFO | __main__ | Epoch 00093: val_loss did not improve from 0.11551
# 2026-07-16 00:21:56 | INFO | __main__ | tag heure: 2026-07-16_00:21:56 (1784128916.232638)
# 2026-07-16 00:21:56 | INFO | __main__ | Epoch 94/100
# 2026-07-16 00:21:56 | INFO | __main__ | 480/480 - 0s - loss: 0.0726 - accuracy: 0.9793 - val_loss: 0.1158 - val_accuracy: 0.9643
# 2026-07-16 00:21:56 | INFO | __main__ | Epoch 00094: val_loss did not improve from 0.11551
# 2026-07-16 00:21:56 | INFO | __main__ | tag heure: 2026-07-16_00:21:56 (1784128916.9333086)
# 2026-07-16 00:21:57 | INFO | __main__ | Epoch 95/100
# 2026-07-16 00:21:57 | INFO | __main__ | 480/480 - 0s - loss: 0.0726 - accuracy: 0.9793 - val_loss: 0.1154 - val_accuracy: 0.9642
# 2026-07-16 00:21:57 | INFO | __main__ | Epoch 00095: val_loss improved from 0.11551 to 0.11541, saving model to outdir/run_20260716-002046/f_weights_out.pth
# 2026-07-16 00:21:57 | INFO | __main__ | tag heure: 2026-07-16_00:21:57 (1784128917.6521175)
# 2026-07-16 00:21:58 | INFO | __main__ | Epoch 96/100
# 2026-07-16 00:21:58 | INFO | __main__ | 480/480 - 0s - loss: 0.0726 - accuracy: 0.9795 - val_loss: 0.1156 - val_accuracy: 0.9638
# 2026-07-16 00:21:58 | INFO | __main__ | Epoch 00096: val_loss did not improve from 0.11541
# 2026-07-16 00:21:58 | INFO | __main__ | tag heure: 2026-07-16_00:21:58 (1784128918.3698537)
# 2026-07-16 00:21:59 | INFO | __main__ | Epoch 97/100
# 2026-07-16 00:21:59 | INFO | __main__ | 480/480 - 0s - loss: 0.0725 - accuracy: 0.9790 - val_loss: 0.1156 - val_accuracy: 0.9636
# 2026-07-16 00:21:59 | INFO | __main__ | Epoch 00097: val_loss did not improve from 0.11541
# 2026-07-16 00:21:59 | INFO | __main__ | tag heure: 2026-07-16_00:21:59 (1784128919.0927627)
# 2026-07-16 00:21:59 | INFO | __main__ | Epoch 98/100
# 2026-07-16 00:21:59 | INFO | __main__ | 480/480 - 0s - loss: 0.0725 - accuracy: 0.9793 - val_loss: 0.1156 - val_accuracy: 0.9640
# 2026-07-16 00:21:59 | INFO | __main__ | Epoch 00098: val_loss did not improve from 0.11541
# 2026-07-16 00:21:59 | INFO | __main__ | tag heure: 2026-07-16_00:21:59 (1784128919.8118684)
# 2026-07-16 00:22:00 | INFO | __main__ | Epoch 99/100
# 2026-07-16 00:22:00 | INFO | __main__ | 480/480 - 0s - loss: 0.0725 - accuracy: 0.9791 - val_loss: 0.1157 - val_accuracy: 0.9640
# 2026-07-16 00:22:00 | INFO | __main__ | Epoch 00099: val_loss did not improve from 0.11541
# 2026-07-16 00:22:00 | INFO | __main__ | tag heure: 2026-07-16_00:22:00 (1784128920.4978895)
# 2026-07-16 00:22:01 | INFO | __main__ | Epoch 100/100
# 2026-07-16 00:22:01 | INFO | __main__ | 480/480 - 0s - loss: 0.0725 - accuracy: 0.9794 - val_loss: 0.1156 - val_accuracy: 0.9646
# 2026-07-16 00:22:01 | INFO | __main__ | Epoch 00100: val_loss did not improve from 0.11541
# 2026-07-16 00:22:01 | INFO | __main__ | Training over.

# %% [markdown]
# ## 9. Results

# %% [markdown]
# After training, the best model (selected based on the lowest validation loss) is loaded, and its accuracy is evaluated on the training, validation, and test datasets.

# %%
logger.info("Final evaluation (on test set)")
best_state_dict = torch.load(
    os.path.join(run_dir, f_out_weights), map_location=compute_device
)

try:
    model.load_state_dict(best_state_dict)
    logger.info("n_model_input_features: {n_model_input_features}")
    [_, train_acc, _] = model_eval(
        model,
        train_loader,
        criterion,
        compute_device,
        logger,
        calc_accuracy,
        printPerf,
    )
    train_acc = int(1000000.0 * train_acc.item()) / 1000000.0
    [_, val_acc, _] = model_eval(
        model,
        val_loader,
        criterion,
        compute_device,
        logger,
        calc_accuracy,
        printPerf,
    )
    val_acc = int(1000000.0 * val_acc.item()) / 1000000.0
    [_, test_acc, _] = model_eval(
        model,
        test_loader,
        criterion,
        compute_device,
        logger,
        calc_accuracy,
        printPerf,
    )
    test_acc = int(1000000.0 * test_acc.item()) / 1000000.0
except RuntimeError as e:
    logger.info(f"Error while loading state_dict : {e}")
    train_acc = float("nan")
    val_acc = float("nan")
    test_acc = float("nan")
time_t5 = time.time()

duration_creation_couche_quantique = int(100.0 * (time_t2 - time_t1)) / 100.0
logger.info(
    "Duration - Quantum layer creation: {}s".format(
        duration_creation_couche_quantique
    )
)
duration_calcul_quantum_features = int(100.0 * (time_t3 - time_t2)) / 100.0
logger.info(
    "Duration - Quantum features encoding: {}s".format(
        duration_calcul_quantum_features
    )
)
duration_qfeatures = (
    duration_creation_couche_quantique + duration_calcul_quantum_features
)
duration_train = int(100.0 * (time_t4 - time_t3)) / 100.0
logger.info("Duration - training: {}s".format(duration_train))
duration_totale = int(100.0 * (time_t5 - time_t1)) / 100.0
logger.info("Duration - total: {}s".format(duration_totale))
logger.info("Best val epoch: {}".format(best_val_epoch))

# Afficher les accuracies après apprentissage
logger.info("Accuracies - train: {:.4f}, val: {:.4f}, test: {:.4f}".format(
    train_acc,
    val_acc,
    test_acc
))
# Out:
# 2026-07-16 00:22:01 | INFO | __main__ | Final evaluation (on test set)
# 2026-07-16 00:22:01 | INFO | __main__ | n_model_input_features: {n_model_input_features}
# 2026-07-16 00:22:01 | INFO | __main__ | 480/480 - 0s - loss: 0.0719 - accuracy: 0.9796
# 2026-07-16 00:22:01 | INFO | __main__ | 120/120 - 0s - loss: 0.1154 - accuracy: 0.9642
# 2026-07-16 00:22:01 | INFO | __main__ | 100/100 - 0s - loss: 0.1103 - accuracy: 0.9675
# 2026-07-16 00:22:01 | INFO | __main__ | Duration - Quantum layer creation: 0.95s
# 2026-07-16 00:22:01 | INFO | __main__ | Duration - Quantum features encoding: 3.12s
# 2026-07-16 00:22:01 | INFO | __main__ | Duration - training: 70.97s
# 2026-07-16 00:22:01 | INFO | __main__ | Duration - total: 75.71s
# 2026-07-16 00:22:01 | INFO | __main__ | Best val epoch: 95
# 2026-07-16 00:22:01 | INFO | __main__ | Accuracies - train: 0.9796, val: 0.9642, test: 0.9675

# %% [markdown]
# ## Conclusion
#
# This notebook successfully **reproduces and occasionally surpasses** the reference results (**99.06% train accuracy, 97.10% test accuracy** with 3 photons and 20 modes), serving as a **proof of concept** for the advantages of **quantum feature extraction** in machine learning.
#
# ### Key Findings
# - **Performance Validation**: The hybrid QORC model (quantum reservoir + linear classifier) matches the original benchmarks, confirming the **effectiveness of quantum features** for MNIST classification.
# - **Quantum Advantage**: The photonic circuit's ability to generate **highly non-linear features**—intractable for classical methods—demonstrates the potential of quantum-enhanced approaches.
# - **Scalability**: While this experiment uses a modest configuration (3 photons, 20 modes), the exponential scaling of the Fock space suggests even greater benefits for larger systems.
# - **NISQ Compatibility**:
#    The QORC architecture is inherently **robust to noise**, as it relies on **repeatable quantum feature patterns** rather than precise quantum state fidelity. This makes it a promising candidate for deployment on **current-generation NISQ (Noisy Intermediate-Scale Quantum) devices**, where systematic errors can be mitigated through statistical repetition.

# %% [markdown]
# ## Environment Setup
# The notebook was tested with the following library versions:

# %%
import sys
import sklearn
import matplotlib

print(f"Python: {sys.version}")
print(f"NumPy: {np.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
print(f"Matplotlib: {matplotlib.__version__}")
print(f"PyTorch: {torch.__version__}")
print(f"Perceval: {pcvl.__version__}")
print(f"MerLin: {ML.__version__}")
# Out:
# Python: 3.12.3 (main, Jun 19 2026, 12:46:00) [GCC 13.3.0]
# NumPy: 2.4.4
# Scikit-learn: 1.9.0
# Matplotlib: 3.10.9
# PyTorch: 2.12.1+cu130
# Perceval: 1.2.4
# MerLin: 0.4.0

# %% [markdown]
# ```
# Python: 3.12.12 | packaged by conda-forge | (main, Oct 13 2025, 14:23:59) [MSC v.1944 64 bit (AMD64)]
# NumPy: 2.3.3
# Scikit-learn: 1.7.1
# Matplotlib: 3.10.7
# PyTorch: 2.7.1+cpu
# Perceval: 0.13.2
# MerLin: 0.1.0
# ```
